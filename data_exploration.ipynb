# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import time
from sklearn import metrics

# %%
path = "./raw.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    acoustic_data  time_to_failure
# 0             12           1.4691
# 1              6           1.4691
# 2              8           1.4691
# 3              5           1.4691
# 4              8           1.4691

# %%
y = df["time_to_failure"]
x = df["acoustic_data"]

# %%
len(y)
# Out:
# 629145480

# %%
def sigmoid(x, derivative=False):
    sigm = 1. / (1. + np.exp(-x))
    if derivative:
        return sigm * (1. - sigm)
    return sigm

# %%
y_train = y.iloc[:300000000]
x_train = x.iloc[:300000000]

# %%
plt.figure(figsize=(30,10))
plt.plot(y_train,x_train)

# %%
x_test = x.iloc[300000000:400000000]
